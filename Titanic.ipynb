# %%
### READ THE README.md FILE
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
tdata = pd.read_csv('C:/Users/sony/test/exploratory_data_analysis/Pandas_labs/pandas-titanic-lab/train.csv')

# %%
tdata.sample(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 413          414         0       2
# 299          300         1       1
# 35            36         0       1
# 459          460         0       3
# 1              2         1       1
# 575          576         0       3
# 198          199         1       3
# 851          852         0       3
# 518          519         1       2
# 749          750         0       3
# 669          670         1       1
# 204          205         1       3
# 80            81         0       3
# 702          703         0       3
# 632          633         1       1
# 680          681         0       3
# 70            71         0       2
# 668          669         0       3
# 619          620         0       2
# 458          459         1       2
# 803          804         1       3
# 377          378         0       1
# 258          259         1       1
# 494          495         0       3
# 754          755         1       2
# ...

# %%
tdata.isnull().sum().plot(kind='bar');         # visually
plt.title('Number of null values per column');

# %%
tdata.count().idxmin()
# Out:
# 'Cabin'

# %%
tdata.isna().sum().idxmax()
# Out:
# 'Cabin'

# %%
#check it 
tdata.dropna(subset = ['Embarked'], inplace=True)

# %%
tdata.sample(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 254          255         0       3
# 66            67         1       2
# 328          329         1       3
# 635          636         1       2
# 139          140         0       1
# 614          615         0       3
# 96            97         0       1
# 499          500         0       3
# 853          854         1       1
# 470          471         0       3
# 83            84         0       1
# 311          312         1       1
# 178          179         0       2
# 295          296         0       1
# 59            60         0       3
# 703          704         0       3
# 549          550         1       2
# 161          162         1       2
# 181          182         0       2
# 564          565         0       3
# 506          507         1       2
# 405          406         0       2
# 246          247         0       3
# 241          242         1       3
# 494          495         0       3
# ...

# %%
tdata.Cabin.fillna(value='**¯\\_(ツ)_/¯**',inplace=True)

# %%
tdata.sample(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 388          389         0       3
# 285          286         0       3
# 196          197         0       3
# 557          558         0       1
# 118          119         0       1
# 537          538         1       1
# 63            64         0       3
# 568          569         0       3
# 134          135         0       2
# 307          308         1       1
# 464          465         0       3
# 621          622         1       1
# 354          355         0       3
# 500          501         0       3
# 725          726         0       3
# 662          663         0       1
# 754          755         1       2
# 554          555         1       3
# 389          390         1       2
# 780          781         1       3
# 493          494         0       1
# 444          445         1       3
# 525          526         0       3
# 442          443         0       3
# 415          416         0       3
# ...

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    889 non-null int64
# Survived       889 non-null int64
# Pclass         889 non-null int64
# Name           889 non-null object
# Sex            889 non-null object
# Age            712 non-null float64
# SibSp          889 non-null int64
# Parch          889 non-null int64
# Ticket         889 non-null object
# Fare           889 non-null float64
# Cabin          889 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.3+ KB

# %%
tdata['FamilyCount']=tdata.SibSp+tdata.Parch

# %%
tdata.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 196          197         0       3                Mernagh, Mr. Robert    male
# 79            80         1       3           Dowdell, Miss. Elizabeth  female
# 689          690         1       1  Madill, Miss. Georgette Alexandra  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 346          347         1       2          Smith, Miss. Marion Elsie  female
#
#       Age  SibSp  Parch    Ticket      Fare          Cabin Embarked  \
# 196   NaN      0      0    368703    7.7500  **¯\_(ツ)_/¯**        Q
# 79   30.0      0      0    364516   12.4750  **¯\_(ツ)_/¯**        S
# 689  15.0      0      1     24160  211.3375             B5        S
# 792   NaN      8      2  CA. 2343   69.5500  **¯\_(ツ)_/¯**        S
# 346  40.0      0      0     31418   13.0000  **¯\_(ツ)_/¯**        S
#
#      FamilyCount
# 196            0
# 79             0
# 689            1
# ...

# %%
tdata['IsReverend']='1' if [tdata['Name'].str.contains('Rev.')] else '0'

# %%
#tdata['IsReverend']='1' if [tdata['Name'].str.contains('Rev.')] = True else ='0'

# %%
tdata.sample(3)
# Out:
#      PassengerId  Survived  Pclass                       Name   Age  SibSp  \
# 371          372         0       3  Wiklund, Mr. Jakob Alfred  18.0      1
# 72            73         0       2       Hood, Mr. Ambrose Jr  21.0      0
# 409          410         0       3         Lefebre, Miss. Ida   NaN      3
#
#      Parch        Ticket     Fare          Cabin  FamilyCount  IsReverend  \
# 371      0       3101267   6.4958  **¯\_(ツ)_/¯**            1           0
# 72       0  S.O.C. 14879  73.5000  **¯\_(ツ)_/¯**            0           0
# 409      1          4133  25.4667  **¯\_(ツ)_/¯**            4           0
#
#      Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male
# 371           0           0           1           0         1
# 72            0           0           1           0         1
# 409           0           0           1           1         0

# %%
def is_reverend(value):
    strings = value.split()
    if 'Rev.' in str(strings):
        return 1
    else:
        return 0

# %%
tdata['IsReverend'] = tdata['Name'].apply(is_reverend)

# %%
tdata.sample(2)
# Out:
#      PassengerId  Survived  Pclass                   Name  Age  SibSp  Parch  \
# 459          460         0       3  O'Connor, Mr. Maurice  NaN      0      0
# 154          155         0       3  Olsen, Mr. Ole Martin  NaN      0      0
#
#         Ticket    Fare          Cabin  FamilyCount  IsReverend  Embarked_C  \
# 459     371060  7.7500  **¯\_(ツ)_/¯**            0           0           0
# 154  Fa 265302  7.3125  **¯\_(ツ)_/¯**            0           0           0
#
#      Embarked_Q  Embarked_S  Sex_female  Sex_male
# 459           1           0           0         1
# 154           0           1           0         1

# %%
#Embarked_C`, `Embarked_Q` and `Embarked_S`
#Sex
tdata = pd.get_dummies(tdata, columns=['Embarked'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-04db98fbf992> in <module>
#       1 #Embarked_C`, `Embarked_Q` and `Embarked_S`
#       2 #Sex
# ----> 3 tdata = pd.get_dummies(tdata, columns=['Embarked'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     870             data_to_encode = data.select_dtypes(include=dtypes_to_encode)
#     871         else:
# --> 872             data_to_encode = data[columns]
#     873
#     874         # validate prefixes and separator to avoid silently dropping cols
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# ...

# %%
tdata.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
#
#              Ticket     Fare          Cabin  FamilyCount  IsReverend  \
# 0         A/5 21171   7.2500  **¯\_(ツ)_/¯**            1           0
# 1          PC 17599  71.2833            C85            1           0
# 2  STON/O2. 3101282   7.9250  **¯\_(ツ)_/¯**            0           0
#
#    Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male
# 0           0           0           1           0         1
# 1           1           0           0           1         0
# 2           0           0           1           1         0

# %%
tdata = pd.get_dummies(tdata, columns=['Sex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-6a0cd13241df> in <module>
# ----> 1 tdata = pd.get_dummies(tdata, columns=['Sex'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     870             data_to_encode = data.select_dtypes(include=dtypes_to_encode)
#     871         else:
# --> 872             data_to_encode = data[columns]
#     873
#     874         # validate prefixes and separator to avoid silently dropping cols
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ...

# %%
tdata.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
#
#              Ticket     Fare          Cabin  FamilyCount  IsReverend  \
# 0         A/5 21171   7.2500  **¯\_(ツ)_/¯**            1           0
# 1          PC 17599  71.2833            C85            1           0
# 2  STON/O2. 3101282   7.9250  **¯\_(ツ)_/¯**            0           0
#
#    Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male
# 0           0           0           1           0         1
# 1           1           0           0           1         0
# 2           0           0           1           1         0

# %%
#pd.get_dummies(d["gen"],prefix='g')
#Extract the title from everyone's name and create dummy columns
# What was the survival rate overall?
tdata.Survived.value_counts()
# Out:
# 0    549
# 1    340
# Name: Survived, dtype: int64
